# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Most effective treatment regimens are Capomulin and Ramicane, with no outliers.
# - Overall Capomulin appears to be the less effective of the two.
# - When viewing data separated by the mouse sex, Capomulin is more effective on the males.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
import seaborn as sns

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
combined_data = pd.merge(study_results,mouse_metadata, on='Mouse ID')


# Display the data table for preview
combined_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
mouse_count = combined_data['Mouse ID'].nunique()
mouse_count
# Out:
# 249

# %%
# Find duplicate mice based on Mouse ID and Timepoint
duplicate_mice = combined_data[combined_data.duplicated(subset=['Mouse ID', 'Timepoint'], keep=False)]

# Get the unique Mouse IDs that are duplicated
duplicate_mouse_ids = duplicate_mice['Mouse ID'].unique()
duplicate_mouse_ids
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
# Identify the duplicate mouse ID
duplicate_mouse_id = duplicate_mice['Mouse ID'].unique()[0]

# Get all data for the duplicate mouse ID
duplicate_mouse_data = combined_data[combined_data['Mouse ID'] == duplicate_mouse_id]

# Display the data for the duplicate mouse ID
duplicate_mouse_data
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
# 870     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mice by their IDs
# Using ~ to negate boolean series so if Mouse ID is in the duplicate_mouse_ids DF it's removed from the cleaned dataframe
cleaned_data = combined_data[~combined_data['Mouse ID'].isin(duplicate_mouse_ids)]
cleaned_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1  Female           9          22
# 2  Female           9          22
# 3  Female           9          22
# 4  Female           9          22

# %%
# Checking the number of mice in the clean DataFrame.
mouse_count2 = cleaned_data['Mouse ID'].nunique()
mouse_count2
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
summary_stats = cleaned_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg(['mean', 'median', 'var', 'std', 'sem'])

# Rename columns for clarity
summary_stats = summary_stats.rename(columns={
    'mean': 'Mean Tumor Volume',
    'median': 'Median Tumor Volume',
    'var': 'Tumor Volume Variance',
    'std': 'Tumor Volume Std. Dev.',
    'sem': 'Tumor Volume SEM'
})

# Display the summary statistics table
summary_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume SEM
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
summary_stats_advanced = cleaned_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg(['mean', 'median', 'var', 'std', 'sem'])\
    .rename(columns={'mean': 'Mean (mm3)', 
                     'median': 'Median (mm3)',
                     'var': 'Variance (mm3)',
                     'std': 'Std. Dev. (mm3)', 
                     'sem': 'SEM (mm3)'})

# Display the advanced summary statistics table
summary_stats_advanced
# Out:
#               Mean (mm3)  Median (mm3)  Variance (mm3)  Std. Dev. (mm3)  \
# Drug Regimen
# Capomulin      40.675741     41.557809       24.947764         4.994774
# Ceftamin       52.591172     51.776157       39.290177         6.268188
# Infubinol      52.884795     51.820584       43.128684         6.567243
# Ketapril       55.235638     53.698743       68.553577         8.279709
# Naftisol       54.331565     52.509285       66.173479         8.134708
# Placebo        54.033581     52.288934       61.168083         7.821003
# Propriva       52.320930     50.446266       43.852013         6.622085
# Ramicane       40.216745     40.673236       23.486704         4.846308
# Stelasyn       54.233149     52.431737       59.450562         7.710419
# Zoniferol      53.236507     51.818479       48.533355         6.966589
#
#               SEM (mm3)
# Drug Regimen
# Capomulin      0.329346
# Ceftamin       0.469821
# Infubinol      0.492236
# Ketapril       0.603860
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.


## Calculate the total number of rows for each drug regimen
bar_plot_data = cleaned_data['Drug Regimen'].value_counts()

# Order the data by total number of rows
bar_plot_data = bar_plot_data.sort_values(ascending=False)

# Plot the bar chart
bar_plot_data.plot(kind='bar', color='lavender', alpha=0.7, edgecolor='slateblue', figsize=(8, 5))

# Add labels and title
plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse Timepoints')

# Display the plot
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.


# Order the data by total number of rows
bar_plot_data = bar_plot_data.sort_values(ascending=False)

# Plot the bar chart using pyplot
plt.figure(figsize=(8, 5))
plt.bar(bar_plot_data.index, bar_plot_data, color='paleturquoise', alpha=0.7, edgecolor='darkcyan')

# Add labels and title
plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse Timepoints')

# Rotate x-axis labels for better readability (optional)
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

# Calculate the distribution of female and male mice
gender_distribution = cleaned_data['Sex'].value_counts()

# Plot the pie chart using Pandas
gender_distribution.plot(kind='pie', autopct='%1.1f%%', colors=['dodgerblue', 'violet'], startangle=0, figsize=(5, 5))

# Add title and lable
plt.title('Distribution of Female vs Male Mice')
plt.ylabel('Sex')

# Display the plot
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# Plot the pie chart using pyplot
plt.figure(figsize=(5, 5))
plt.pie(gender_distribution, labels=gender_distribution.index, autopct='%1.1f%%', colors=['dodgerblue', 'violet'], startangle=0)

# Add title
plt.title('Distribution of Female vs Male Mice')
plt.ylabel('Sex')

# Display the plot
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

selected_regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# %%
# Filter the data for the selected regimens
final_tumor_data = cleaned_data[cleaned_data['Drug Regimen'].isin(selected_regimens)]


# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = final_tumor_data.groupby('Mouse ID')['Timepoint'].max()
last_timepoint_df = pd.DataFrame(last_timepoint).reset_index()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
final_tumor_volume = pd.merge(last_timepoint_df, cleaned_data, on=['Mouse ID', 'Timepoint'], how='left')

# Display the final tumor volume data
final_tumor_volume.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     a203         45           67.973419                 2    Infubinol
# 1     a251         45           65.525743                 1    Infubinol
# 2     a275         45           62.999356                 3     Ceftamin
# 3     a411         45           38.407618                 1     Ramicane
# 4     a444         45           43.047543                 0     Ramicane
#
#       Sex  Age_months  Weight (g)
# 0  Female          20          23
# 1  Female          21          25
# 2  Female          20          28
# 3    Male           3          22
# 4  Female          10          25

# %%
# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# Iterate through each regimen
for regimen in selected_regimens:
    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumor_vol_subset = final_tumor_volume.loc[final_tumor_volume['Drug Regimen'] == regimen, 'Tumor Volume (mm3)']
    
    # Add subset to the list
    tumor_vol_data.append(tumor_vol_subset)
    
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
# Locate the rows which contain mice on each drug and get the tumor volumes
# add subset 
    quartiles = tumor_vol_subset.quantile([0.25, 0.5, 0.75])
    lower_q = quartiles[0.25]
    upper_q = quartiles[0.75]
    iqr = upper_q - lower_q

    
    # Determine outliers using upper and lower bounds
    lower_bound = lower_q - 1.5 * iqr
    upper_bound = upper_q + 1.5 * iqr
    
    # Identify potential outliers
    outliers = tumor_vol_subset[(tumor_vol_subset < lower_bound) | (tumor_vol_subset > upper_bound)]
    
    # Print results
    print(f"{regimen} potential outliers: {outliers.tolist()}")

# Display the tumor volume data for each regimen
# Out:
# Capomulin potential outliers: []
# Ramicane potential outliers: []
# Infubinol potential outliers: [36.3213458]
# Ceftamin potential outliers: []

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
# Create a list to store tumor volume data for plotting
tumor_vol_data = []

# Iterate through each regimen
for regimen in selected_regimens:
    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumor_vol_subset = final_tumor_volume.loc[final_tumor_volume['Drug Regimen'] == regimen, 'Tumor Volume (mm3)']
    # Add subset to the list
    tumor_vol_data.append(tumor_vol_subset)

# Create a box plot
plt.figure(figsize=(7,5))
plt.boxplot(tumor_vol_data, labels=selected_regimens, sym='ro')

# Add labels and title
plt.title('Distribution of Tumor Volume for Each Treatment Group')
plt.xlabel('Drug Regimen')
plt.ylabel('Tumor Volume (mm3)')

# Display the plot
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
selected_mouse = 's185' 

# Filter data for the selected mouse and Capomulin regimen
mouse_capomulin_data = cleaned_data[(cleaned_data['Mouse ID'] == selected_mouse) & (cleaned_data['Drug Regimen'] == 'Capomulin')]

# Create a line plot of tumor volume vs. time point
plt.figure(figsize=(10, 6))
plt.plot(mouse_capomulin_data['Timepoint'], mouse_capomulin_data['Tumor Volume (mm3)'],  linestyle='-', color='darkolivegreen')

# Add labels and title
plt.title(f'Tumor Volume vs. Time Point for Mouse {selected_mouse} (Capomulin)')
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume (mm3)')

# Display the plot
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
# Filter data for Capomulin regimen
capomulin_data = cleaned_data[cleaned_data['Drug Regimen'] == 'Capomulin']

# Calculate the average observed tumor volume for each mouse
average_tumor_volume = capomulin_data.groupby('Mouse ID')['Tumor Volume (mm3)'].mean()

# Merge average tumor volume data with the mouse weight data
merged_data = pd.merge(average_tumor_volume, mouse_metadata, on='Mouse ID', how='inner')

# Create a scatter plot of mouse weight vs. average observed tumor volume
plt.figure(figsize=(7, 5))
plt.scatter(merged_data['Weight (g)'], merged_data['Tumor Volume (mm3)'], color='gold', alpha=0.7, edgecolors='black')

# Add labels and title
plt.title('Mouse Weight vs. Average Tumor Volume (Capomulin)')
plt.xlabel('Mouse Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')

# Display the plot
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen


# Calculate the average observed tumor volume for each mouse
average_tumor_volume = capomulin_data.groupby('Mouse ID')['Tumor Volume (mm3)'].mean()

# Merge average tumor volume data with the mouse weight data
merged_data = pd.merge(average_tumor_volume, mouse_metadata, on='Mouse ID', how='inner')

# Calculate the correlation coefficient
correlation_coefficient = merged_data['Weight (g)'].corr(merged_data['Tumor Volume (mm3)'])

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(merged_data['Weight (g)'], merged_data['Tumor Volume (mm3)'])

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(merged_data['Weight (g)'], merged_data['Tumor Volume (mm3)'], color='steelblue', alpha=0.9)

# Plot the linear regression line
regress_values = merged_data['Weight (g)'] * slope + intercept
plt.plot(merged_data['Weight (g)'], regress_values, color='r', linestyle='--', linewidth=2)

# Add labels and title
plt.title('Mouse Weight vs. Average Tumor Volume (Capomulin Regimen)')
plt.xlabel('Mouse Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')

# Display the plot
plt.show()

# %%
# Display correlation coefficient and regression information
print(f"Correlation Coefficient: {correlation_coefficient}")
print(f"Linear Regression Model: y = {slope:.2f}x + {intercept:.2f}")
# Out:
# Correlation Coefficient: 0.8419363424694722
# Linear Regression Model: y = 0.95x + 21.55

# %% [markdown]
# ### Plotting Tumor Volume vs Timepoint for All Regimens

# %%
# Set a color palette for each drug regimen
palette = sns.color_palette("husl", n_colors=len(cleaned_data['Drug Regimen'].unique()))

# Create a line plot with trend lines for each drug regimen
plt.figure(figsize=(12, 8))
sns.lmplot(x='Timepoint', y='Tumor Volume (mm3)', data=cleaned_data, hue='Drug Regimen', palette=palette, height=6, aspect=1.5, ci=None)

# Add labels and title
plt.title('Tumor Volume vs. Time Point with Trend Lines for Different Drug Regimens')
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume (mm3)')

# Display the plot
plt.grid(True)
plt.show()
# Out:
# C:\Users\steve\anaconda3\envs\dev\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Plotting Tumor Volume vs Timepoint on 4 Main Regimens
# #### ('Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin')

# %%
# Filter the data for the selected drug regimens
selected_data = cleaned_data[cleaned_data['Drug Regimen'].isin(selected_regimens)]

# Set a color palette for the selected drug regimens
palette = sns.color_palette("husl", n_colors=len(selected_regimens))

# Create a line plot with trend lines for the selected drug regimens
plt.figure(figsize=(16, 12))
sns.lmplot(x='Timepoint', y='Tumor Volume (mm3)', data=selected_data, hue='Drug Regimen', palette=palette, height=6, aspect=1.5, ci=None)

# Add labels and title
plt.title('Tumor Volume vs. Time Point with Trend Lines for Selected Drug Regimens')
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume (mm3)')

# Display the plot
plt.grid(True)
plt.show()
# Out:
# C:\Users\steve\anaconda3\envs\dev\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Specify the drug regimens of interest
selected_regimens = ['Capomulin', 'Ramicane']

# Filter the data for the selected drug regimens
selected_data = cleaned_data[cleaned_data['Drug Regimen'].isin(selected_regimens)]

# Set a color palette for the selected drug regimens and genders
palette = sns.color_palette("husl", n_colors=len(selected_regimens) * len(cleaned_data['Sex'].unique()))

# Create a line plot with separate colors and trend lines for each combination of drug regimen and gender
plt.figure(figsize=(12, 8))
sns.lmplot(x='Timepoint', y='Tumor Volume (mm3)', data=selected_data, hue='Drug Regimen', col='Sex', palette=palette, height=6, aspect=1.5, ci=None)

# Add labels and title
plt.suptitle('Tumor Volume vs. Time Point with Trend Lines for Capomulin and Ramicane, Categorized by Gender', y=1.02)
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume (mm3)')

# Display the plot
plt.show()
# Out:
# C:\Users\steve\anaconda3\envs\dev\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
